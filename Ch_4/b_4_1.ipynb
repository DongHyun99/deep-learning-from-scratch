# %% [markdown]
# # 4 신경망 학습
#
#     - 학습: 훈련 데이터로부터 가중치 매개변수의 최적 값을 자동으로 획득하는 것을 뜻한다.
#     - 손실 함수: 손실함수의 결과 값을 가장작게 만드는 것이 목표 -> 경사법 소개
#
# 4 신경망 학습
#
#     - 학습: 훈련 데이터로부터 가중치 매개변수의 최적 값을 자동으로 획득하는 것을 뜻한다.
#     - 손실 함수: 손실함수의 결과 값을 가장작게 만드는 것이 목표 -> 경사법 소개
#
# # 4.1 데이터에서 학습한다!
#
# 신경망은 데이터를 보고 매개변수의 값을 자동으로 결정한다.
#
# ## 4.1.1 데이터 주도 학습
#
# 알고리즘을 밑바닥부터 설계하는대신 주어진 데이터를 잘 활용해서 해결하는 방법 중 하나
# 특징은 입력 데이터에서 중요한 데이터를 정확하게 추출할 수 있도록 설계된 변환기를 의미한다.
# 이미지의 특징은 보통 벡터로 기술, 컴퓨터 비전 분야에서는 SIFT, SURF, HOG 등을 사용하기도 한다.
# SVM, KNN 등도 있음
#
# 다만 이러한 방식들은 사람이 설계하므로 항상 최적의 결과를 얻기는 어려움
# 고리즘을 밑바닥부터 설계하는대신 주어진 데이터를 잘 활용해서 해결하는 방법 중 하나
# 특징은 입력 데이터에서 중요한 데이터를 정확하게 추출할 수 있도록 설계된 변환기를 의미한다.
# 이미지의 특징은 보통 벡터로 기술, 컴퓨터 비전 분야에서는 SIFT, SURF, HOG 등을 사용하기도 한다.
# SVM, KNN 등도 있음
#
# 다만 이러한 방식들은 사람이 설계하므로 항상 최적의 결과를 얻기는 어려움
# 반면 딥러닝 방식은 사람이 개입하지 않는 블록 하나로 그려짐
#
#  딥려닝은 있는 그대로를 학습하고 모든 문제에 대해서 같은 맥락에서 풀수 있다는 이점이 있다. (end - to - end))
#
#
# ## 4.1.2 훈련 데이터와 시험 데이터
#
# 기계학습 문제는 training data와 test data로 나눠 학습과 실험을 수행 하는 것이 일반적이다.
# 범용적으로 사용이 가능한 모델을 만들어야 하기 때문 (over fiting 되지 않게 하지 위해서)
